# %%
1-

# %%
idade = int(input("Digite sua idade: "))

if idade >=12:
    tem_ingresso= input("Esta com ingresso? (Estou/Não estou): ")
    
    if tem_ingresso== "Estou":
        print("Entrada liberada")
        
    else:
        print("Precisa comprar ingresso!")

else:
    print("Idade insuficiente!")
# Out:
# Digite sua idade:  14
# Esta com ingresso? (Estou/Não estou):  Estou
# Entrada liberada

# %%
2-

# %%
name = input("Digite seu nome: ")

if name== "Admin":
    senha_usuario = int(input("Digite sua senha:"))

    if senha_usuario == 1234:
        print("Acesso permitido")

    else:
        print("Senha incorreta")

else:
    print("Usuario invalido")
# Out:
# Digite seu nome:  Admin
# Digite sua senha: 1234
# Acesso permitido

# %%
3-

# %%
grade = int(input("Digite sua nota: "))

if grade >=7:
    freq_aluno = int(input("Digite sua frequencia: "))
    if freq_aluno >=75:
        print("Aprovado.")

    else:
        print("Reprovado por falta")

else:
    print("Reprovado por nota")
# Out:
# Digite sua nota:  10
# Digite sua frequencia:  34
# Reprovado por falta

# %%
4-

# %%
n = int(input("Digite um numero inteiro: "))

if n >0:
    if n %2==0:
        print("Par positivo")

    else:
        print("Ímpar positivo")

else:
    print("Número não positivo")
# Out:
# Digite um numero inteiro:  12
# Par positivo

# %%
5-

# %%
age = int(input("Digite sua idade: "))

if age >=16:
    tem_doc= input("Esta com documento? (Sim/Não): ")
    
    if tem_doc== "Sim":
        print("Pode entrar")
        
    else:
        print("Precisa apresentar seu documento!")

else:
    print("Entrada não permitida!")
# Out:
# Digite sua idade:  17
# Esta com documento? (Sim/Não):  Sim
# Pode entrar

# %%
6-

# %%
valor_compra = int(input("Digite o valor da compra: "))

if valor_compra >=100:
    tem_cupom= input("Possui cupom ? (Sim/Não): ")
    
    if tem_cupom == "Sim":
        print("Desconto aplicado")
        
    else:
        print("Sem desconto")

else:
    print("Valor insuficiente para desconto!")
# Out:
# Digite o valor da compra:  200
# Possui cupom ? (Sim/Não):  Sim
# Desconto aplicado

# %%
7-

# %%
num = int(input("Digite um número inteiro: "))

if num >0:
    if num %2==0 and num %3==0:
        print("O número é múltiplo de 2 e de 3")

    elif num %2==0:
        print("O número é múltiplo de 2")

    elif num %3==0:
        print("O número é multiplo de 3")

else:
    print("O número não é positivo")
# Out:
# Digite um número inteiro:  4
# O número é múltiplo de 2

# %%
8-

# %%
nome = input("Digite seu nome: ")

if nome.strip ():
    idade = int(input("Qual sua idade?: "))
    
    if idade >=18:
        print("Cadastro completo")
        
    else:
        print("Cadastro incompleto: menor de idade")

elif not nome.strip():
    print("Nome obrigatório")
# Out:
# Digite seu nome:  Diogo
# Qual sua idade?:  20
# Cadastro completo

# %%
9-

# %%
age = int(input("Digite sua idade: "))

if age >=60:
    dor_forte = input("Está com dor forte? (Sim/Não): ")
    
    if dor_forte == "Sim":
        print("Atendimento prioritário imediato!")
        
    else:
        print("Aguardar triagem")

else:
    print("Atendimento comum")
# Out:
# Digite sua idade:  19
# Atendimento comum

# %%
10-

# %%
user = input("Digite o usuário: ")

if user == "Professor":
    senha_user = input("Digite sua senha: ")

    if senha_user == "python123":
        nivel_de_acesso = int(input("Digite o nível de acesso: "))

    if nivel_de_acesso == 1:
        print("Acesso básico")
    
    elif senha_usuario != "python123":
        print("Senha inválida")

    else:
        print("Acesso avançado")

elif user != "professor":
    print("Usuário não autorizado")
# Out:
# Digite o usuário:  Professor
# Digite sua senha:  python123
# Digite o nível de acesso:  1
# Acesso básico
