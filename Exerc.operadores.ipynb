# %%
1 -

# %%
age = int(input("Qual é a sua idade? "))
driver_id = input("Você tem carteira de motorista? (sim/não) ")

if age >= 18 and driver_id == "sim":
    print("Você pode dirigir!")
else:
    print("Você não pode dirigir.")
# Out:
# Qual é a sua idade?  17
# Você tem carteira de motorista? (sim/não)  não
# Você não pode dirigir.

# %%
2-

# %%
num = int ( input (" Digite um nú mero : ") )
if num >= 50 and num <=100:
    print ("Número dentro do intervalo ")
else :
    print ("Número fora do intervalo ")
# Out:
#  Digite um nú mero :  15
# Número fora do intervalo

# %%
3-

# %%
day_week = input("Digite o dia da semana: ")
if day_week =="sábado" or day_week =="domingo":
    print("É final de semana")
else:
    print("É dia de semana")
s
# Out:
# Digite o dia da semana:  Sexta
# É dia de semana
