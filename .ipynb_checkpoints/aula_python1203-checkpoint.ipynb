# %%
x = "Eu estou aprendendo Python"
print(x)
# Out:
# Eu estou aprendendo Python

# %%
j = "Meu nome é Maria"
kl = "Eu moro em Aparecida de Goiânia"
print(j)
print(kl)
# Out:
# Meu nome é Maria
# Eu moro em Aparecida de Goiânia

# %%
nome_do_aluno = "Maria"
idade_do_aluno = "44"
print("Meu nome é ", nome_do_aluno, "e tenho", idade_do_aluno,"anos.")
# Out:
# Meu nome é  Maria e tenho 44 anos.

# %%
c = "Londres"
e = " - Pará, "
p = "Inglaterra."
print("Eu moro em ", c, e, p)
# Out:
# Eu moro em  Londres  - Pará,  Inglaterra.

# %%
En = input("Digite o seu nome: ")
Ci = input("Qual a sua cidade ? ")
print("Olá, ", En, "você mora em ", Ci)
# Out:
# Digite o seu nome:  Diogo
# Qual a sua cidade ?  Goiânia
# Olá,  Diogo você mora em  Goiânia
